# %% [markdown]
# # Gesture Recognition
# In this project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
from scipy.misc import imread, imresize
import datetime
import os

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.set_random_seed(30)
# Out:
# C:\Users\ragarwal\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('./Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('./Project_data/val.csv').readlines())
batch_size = 50 #experiment with the batch size

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = [0,2,6,9,12,15,18,21,24,27] #create a list of image numbers you want to use for a particular video
    while True:
        t = np.random.permutation(folder_list)
        num_sequences = len(folder_list)
        num_batches = int(num_sequences/batch_size) # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,10,120,120,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    if(image.shape[0] == 360 and image.shape[1] == 360): # Resize 360X360 image to 120X120
                        image = imresize(image, (120, 120))
                    else:
                        image = image[:,20:140] # Crop the 120X160 image to 120X120
                    
                    batch_data[folder,idx] = image
                    
                    batch_data[folder,idx,:,:,0] = batch_data[folder,idx,:,:,0] - (np.min(batch_data[folder,idx,:,:,0])/
                                                    np.max(batch_data[folder,idx,:,:,0]) - np.min(batch_data[folder,idx,:,:,0]))
                    batch_data[folder,idx,:,:,1] = batch_data[folder,idx,:,:,1] - (np.min(batch_data[folder,idx,:,:,1])/
                                                    np.max(batch_data[folder,idx,:,:,1]) - np.min(batch_data[folder,idx,:,:,1]))
                    batch_data[folder,idx,:,:,2] = batch_data[folder,idx,:,:,2] - (np.min(batch_data[folder,idx,:,:,2])/
                                                    np.max(batch_data[folder,idx,:,:,2]) - np.min(batch_data[folder,idx,:,:,2]))
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches
        remaining_steps = num_sequences%batch_size
        
        if (remaining_steps) > 0:
            batch_data = np.zeros((remaining_steps,10,120,120,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((remaining_steps,5)) # batch_labels is the one hot representation of the output
            for folder in range(remaining_steps): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (num_batches*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    if(image.shape[0] == 360 and image.shape[1] == 360): # Resize 360X360 image to 120X120
                        image = imresize(image, (120, 120))
                    else:
                        image = image[:,20:140] # Crop the 120X160 image to 120X120
                    
                    batch_data[folder,idx] = image
                    
                    batch_data[folder,idx,:,:,0] = batch_data[folder,idx,:,:,0] - (np.min(batch_data[folder,idx,:,:,0])/
                                                    np.max(batch_data[folder,idx,:,:,0]) - np.min(batch_data[folder,idx,:,:,0]))
                    batch_data[folder,idx,:,:,1] = batch_data[folder,idx,:,:,1] - (np.min(batch_data[folder,idx,:,:,1])/
                                                    np.max(batch_data[folder,idx,:,:,1]) - np.min(batch_data[folder,idx,:,:,1]))
                    batch_data[folder,idx,:,:,2] = batch_data[folder,idx,:,:,2] - (np.min(batch_data[folder,idx,:,:,2])/
                                                    np.max(batch_data[folder,idx,:,:,2]) - np.min(batch_data[folder,idx,:,:,2]))
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = './Project_data/train'
val_path = './Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 100 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 100

# %% [markdown]
# ## Model
# ### 3D Convolutional Model

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

#write your model here

model = Sequential()
model.add(Conv3D(32, (3, 3, 3), padding='same',
                 input_shape=(10,120,120,3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv3D(32, (3, 3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Dropout(0.25))

model.add(Conv3D(64, (3, 3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv3D(64, (3, 3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512,kernel_regularizer=l2(0.01)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(5))
model.add(Activation('softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = optimizers.SGD()#write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1 (Conv3D)            (None, 10, 120, 120, 32)  2624
# _________________________________________________________________
# activation_1 (Activation)    (None, 10, 120, 120, 32)  0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 10, 120, 120, 32)  128
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 8, 118, 118, 32)   27680
# _________________________________________________________________
# activation_2 (Activation)    (None, 8, 118, 118, 32)   0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 118, 118, 32)   128
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 4, 59, 59, 32)     0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 59, 59, 32)     0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 4, 59, 59, 64)     55360
# _________________________________________________________________
# activation_3 (Activation)    (None, 4, 59, 59, 64)     0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 59, 59, 64)     256
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 2, 57, 57, 64)     110656
# _________________________________________________________________
# activation_4 (Activation)    (None, 2, 57, 57, 64)     0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2, 57, 57, 64)     256
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 1, 28, 28, 64)     0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 28, 28, 64)     0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 50176)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               25690624
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 2565
# _________________________________________________________________
# activation_6 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 25,890,277
# Trainable params: 25,889,893
# Non-trainable params: 384
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=5, min_lr=0.001)# write the REducelronplateau code here

callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  ./Project_data/valSource path =  ./Project_data/train ; batch size =Epoch 1/100
#  ; batch size = 50
#  50
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 12/14 [========================>.....] - ETA: 9s - loss: 21.2817 - categorical_accuracy: 0.2167
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:46: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:52: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 14/14 [==============================] - 70s 5s/step - loss: 20.7315 - categorical_accuracy: 0.2384 - val_loss: 22.5267 - val_categorical_accuracy: 0.2300
#
# Epoch 00001: saving model to model_init_2019-06-2305_11_09.891400/model-00001-20.96782-0.23077-22.52668-0.23000.h5
# Epoch 2/100
# 14/14 [==============================] - 37s 3s/step - loss: 14.5030 - categorical_accuracy: 0.4191 - val_loss: 18.3263 - val_categorical_accuracy: 0.2400
#
# Epoch 00002: saving model to model_init_2019-06-2305_11_09.891400/model-00002-14.42102-0.43288-18.32626-0.24000.h5
# Epoch 3/100
# 14/14 [==============================] - 37s 3s/step - loss: 12.5403 - categorical_accuracy: 0.4927 - val_loss: 22.4436 - val_categorical_accuracy: 0.2300
#
# Epoch 00003: saving model to model_init_2019-06-2305_11_09.891400/model-00003-12.40685-0.50226-22.44357-0.23000.h5
# Epoch 4/100
# 14/14 [==============================] - 37s 3s/step - loss: 12.0597 - categorical_accuracy: 0.5773 - val_loss: 11.2851 - val_categorical_accuracy: 0.5200
#
# Epoch 00004: saving model to model_init_2019-06-2305_11_09.891400/model-00004-11.73480-0.60332-11.28509-0.52000.h5
# Epoch 5/100
# 14/14 [==============================] - 37s 3s/step - loss: 12.0567 - categorical_accuracy: 0.5831 - val_loss: 14.1357 - val_categorical_accuracy: 0.3800
#
# Epoch 00005: saving model to model_init_2019-06-2305_11_09.891400/model-00005-11.74244-0.60935-14.13568-0.38000.h5
# Epoch 6/100
# 14/14 [==============================] - 37s 3s/step - loss: 11.3234 - categorical_accuracy: 0.6805 - val_loss: 11.7362 - val_categorical_accuracy: 0.4600
#
# Epoch 00006: saving model to model_init_2019-06-2305_11_09.891400/model-00006-11.10429-0.69985-11.73622-0.46000.h5
# Epoch 7/100
# 14/14 [==============================] - 37s 3s/step - loss: 11.4367 - categorical_accuracy: 0.6916 - val_loss: 11.3275 - val_categorical_accuracy: 0.4200
#
# Epoch 00007: saving model to model_init_2019-06-2305_11_09.891400/model-00007-11.18915-0.71946-11.32752-0.42000.h5
# Epoch 8/100
# 14/14 [==============================] - 37s 3s/step - loss: 11.1058 - categorical_accuracy: 0.6858 - val_loss: 14.7113 - val_categorical_accuracy: 0.2900
#
# Epoch 00008: saving model to model_init_2019-06-2305_11_09.891400/model-00008-10.84002-0.71342-14.71131-0.29000.h5
# Epoch 9/100
# 14/14 [==============================] - 37s 3s/step - loss: 11.1521 - categorical_accuracy: 0.6695 - val_loss: 11.8997 - val_categorical_accuracy: 0.4900
#
# Epoch 00009: saving model to model_init_2019-06-2305_11_09.891400/model-00009-10.95491-0.69231-11.89970-0.49000.h5
# Epoch 10/100
# 14/14 [==============================] - 37s 3s/step - loss: 11.2214 - categorical_accuracy: 0.7016 - val_loss: 10.9143 - val_categorical_accuracy: 0.5900
#
# Epoch 00010: saving model to model_init_2019-06-2305_11_09.891400/model-00010-11.02249-0.73002-10.91432-0.59000.h5
# Epoch 11/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.7863 - categorical_accuracy: 0.7632 - val_loss: 10.9029 - val_categorical_accuracy: 0.5800
#
# Epoch 00011: saving model to model_init_2019-06-2305_11_09.891400/model-00011-10.65758-0.78281-10.90291-0.58000.h5
# Epoch 12/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.6109 - categorical_accuracy: 0.7719 - val_loss: 10.8704 - val_categorical_accuracy: 0.6100
#
# Epoch 00012: saving model to model_init_2019-06-2305_11_09.891400/model-00012-10.43665-0.80392-10.87045-0.61000.h5
# Epoch 13/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.7253 - categorical_accuracy: 0.7958 - val_loss: 10.8457 - val_categorical_accuracy: 0.6000
#
# Epoch 00013: saving model to model_init_2019-06-2305_11_09.891400/model-00013-10.42864-0.83710-10.84570-0.60000.h5
# Epoch 14/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.5589 - categorical_accuracy: 0.7948 - val_loss: 10.7794 - val_categorical_accuracy: 0.6100
#
# Epoch 00014: saving model to model_init_2019-06-2305_11_09.891400/model-00014-10.34786-0.82805-10.77939-0.61000.h5
# Epoch 15/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.5550 - categorical_accuracy: 0.8230 - val_loss: 10.7279 - val_categorical_accuracy: 0.6500
#
# Epoch 00015: saving model to model_init_2019-06-2305_11_09.891400/model-00015-10.30924-0.85370-10.72788-0.65000.h5
# Epoch 16/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.4728 - categorical_accuracy: 0.8278 - val_loss: 10.6980 - val_categorical_accuracy: 0.6400
#
# Epoch 00016: saving model to model_init_2019-06-2305_11_09.891400/model-00016-10.23589-0.86275-10.69803-0.64000.h5
# Epoch 17/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.4755 - categorical_accuracy: 0.8373 - val_loss: 10.7677 - val_categorical_accuracy: 0.6200
#
# Epoch 00017: saving model to model_init_2019-06-2305_11_09.891400/model-00017-10.23103-0.86878-10.76769-0.62000.h5
# Epoch 18/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.4098 - categorical_accuracy: 0.8364 - val_loss: 10.8073 - val_categorical_accuracy: 0.6100
#
# Epoch 00018: saving model to model_init_2019-06-2305_11_09.891400/model-00018-10.20997-0.87179-10.80726-0.61000.h5
# Epoch 19/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.2911 - categorical_accuracy: 0.8564 - val_loss: 10.8012 - val_categorical_accuracy: 0.6400
#
# Epoch 00019: saving model to model_init_2019-06-2305_11_09.891400/model-00019-10.13893-0.88084-10.80122-0.64000.h5
# Epoch 20/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.2813 - categorical_accuracy: 0.8640 - val_loss: 10.7789 - val_categorical_accuracy: 0.6300
#
# Epoch 00020: saving model to model_init_2019-06-2305_11_09.891400/model-00020-10.07819-0.89291-10.77887-0.63000.h5
# Epoch 21/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.3070 - categorical_accuracy: 0.8746 - val_loss: 10.7439 - val_categorical_accuracy: 0.6500
#
# Epoch 00021: saving model to model_init_2019-06-2305_11_09.891400/model-00021-10.07006-0.90799-10.74390-0.65000.h5
# Epoch 22/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.3799 - categorical_accuracy: 0.8679 - val_loss: 10.7332 - val_categorical_accuracy: 0.6600
#
# Epoch 00022: saving model to model_init_2019-06-2305_11_09.891400/model-00022-10.11166-0.90498-10.73316-0.66000.h5
# Epoch 23/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.2085 - categorical_accuracy: 0.8732 - val_loss: 10.6980 - val_categorical_accuracy: 0.6500
#
# Epoch 00023: saving model to model_init_2019-06-2305_11_09.891400/model-00023-10.02974-0.90649-10.69801-0.65000.h5
# Epoch 24/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.2559 - categorical_accuracy: 0.8622 - val_loss: 10.7167 - val_categorical_accuracy: 0.6400
#
# Epoch 00024: saving model to model_init_2019-06-2305_11_09.891400/model-00024-10.05982-0.89894-10.71674-0.64000.h5
# Epoch 25/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.1074 - categorical_accuracy: 0.8998 - val_loss: 10.7424 - val_categorical_accuracy: 0.6400
#
# Epoch 00025: saving model to model_init_2019-06-2305_11_09.891400/model-00025-9.98445-0.91855-10.74241-0.64000.h5
# Epoch 26/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.1760 - categorical_accuracy: 0.8484 - val_loss: 10.7134 - val_categorical_accuracy: 0.6400
#
# Epoch 00026: saving model to model_init_2019-06-2305_11_09.891400/model-00026-10.00274-0.88839-10.71338-0.64000.h5
# Epoch 27/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.2811 - categorical_accuracy: 0.8613 - val_loss: 10.7033 - val_categorical_accuracy: 0.6300
#
# Epoch 00027: saving model to model_init_2019-06-2305_11_09.891400/model-00027-10.03776-0.90196-10.70331-0.63000.h5
# Epoch 28/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.0771 - categorical_accuracy: 0.8927 - val_loss: 10.6729 - val_categorical_accuracy: 0.6500
#
# Epoch 00028: saving model to model_init_2019-06-2305_11_09.891400/model-00028-9.95230-0.92308-10.67286-0.65000.h5
# Epoch 29/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.1870 - categorical_accuracy: 0.8727 - val_loss: 10.6852 - val_categorical_accuracy: 0.6700
#
# Epoch 00029: saving model to model_init_2019-06-2305_11_09.891400/model-00029-9.99140-0.91403-10.68520-0.67000.h5
# Epoch 30/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.0635 - categorical_accuracy: 0.8994 - val_loss: 10.6678 - val_categorical_accuracy: 0.6700
#
# Epoch 00030: saving model to model_init_2019-06-2305_11_09.891400/model-00030-9.94779-0.92609-10.66784-0.67000.h5
# Epoch 31/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.1132 - categorical_accuracy: 0.8861 - val_loss: 10.6091 - val_categorical_accuracy: 0.6700
#
# Epoch 00031: saving model to model_init_2019-06-2305_11_09.891400/model-00031-9.96793-0.92006-10.60908-0.67000.h5
# Epoch 32/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.1522 - categorical_accuracy: 0.8884 - val_loss: 10.5953 - val_categorical_accuracy: 0.6900
#
# Epoch 00032: saving model to model_init_2019-06-2305_11_09.891400/model-00032-9.95915-0.91855-10.59525-0.69000.h5
# Epoch 33/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.2376 - categorical_accuracy: 0.8823 - val_loss: 10.5869 - val_categorical_accuracy: 0.6700
#
# Epoch 00033: saving model to model_init_2019-06-2305_11_09.891400/model-00033-9.96416-0.92006-10.58687-0.67000.h5
# Epoch 34/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.1485 - categorical_accuracy: 0.8990 - val_loss: 10.6103 - val_categorical_accuracy: 0.6700
#
# Epoch 00034: saving model to model_init_2019-06-2305_11_09.891400/model-00034-9.90187-0.93363-10.61025-0.67000.h5
# Epoch 35/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.1738 - categorical_accuracy: 0.8708 - val_loss: 10.6004 - val_categorical_accuracy: 0.6300
#
# Epoch 00035: saving model to model_init_2019-06-2305_11_09.891400/model-00035-9.95114-0.90799-10.60038-0.63000.h5
# Epoch 36/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.1454 - categorical_accuracy: 0.9089 - val_loss: 10.6158 - val_categorical_accuracy: 0.6700
#
# Epoch 00036: saving model to model_init_2019-06-2305_11_09.891400/model-00036-9.92407-0.93213-10.61581-0.67000.h5
# Epoch 37/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.1731 - categorical_accuracy: 0.8846 - val_loss: 10.6156 - val_categorical_accuracy: 0.6500
#
# Epoch 00037: saving model to model_init_2019-06-2305_11_09.891400/model-00037-9.95389-0.91855-10.61564-0.65000.h5
# Epoch 38/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.0088 - categorical_accuracy: 0.9085 - val_loss: 10.6150 - val_categorical_accuracy: 0.6300
#
# Epoch 00038: saving model to model_init_2019-06-2305_11_09.891400/model-00038-9.85896-0.93967-10.61500-0.63000.h5
# Epoch 39/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.1373 - categorical_accuracy: 0.9056 - val_loss: 10.6331 - val_categorical_accuracy: 0.6600
#
# Epoch 00039: saving model to model_init_2019-06-2305_11_09.891400/model-00039-9.90456-0.93665-10.63307-0.66000.h5
# Epoch 40/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.0565 - categorical_accuracy: 0.8956 - val_loss: 10.6114 - val_categorical_accuracy: 0.6600
#
# Epoch 00040: saving model to model_init_2019-06-2305_11_09.891400/model-00040-9.88722-0.92609-10.61143-0.66000.h5
# Epoch 41/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.1128 - categorical_accuracy: 0.8980 - val_loss: 10.6294 - val_categorical_accuracy: 0.6500
#
# Epoch 00041: saving model to model_init_2019-06-2305_11_09.891400/model-00041-9.87770-0.93665-10.62943-0.65000.h5
# Epoch 42/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.0172 - categorical_accuracy: 0.8994 - val_loss: 10.6179 - val_categorical_accuracy: 0.6600
#
# Epoch 00042: saving model to model_init_2019-06-2305_11_09.891400/model-00042-9.85700-0.92609-10.61785-0.66000.h5
# Epoch 43/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.9932 - categorical_accuracy: 0.9109 - val_loss: 10.6070 - val_categorical_accuracy: 0.6600
#
# Epoch 00043: saving model to model_init_2019-06-2305_11_09.891400/model-00043-9.83214-0.93816-10.60696-0.66000.h5
# Epoch 44/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.0502 - categorical_accuracy: 0.9004 - val_loss: 10.6194 - val_categorical_accuracy: 0.6400
#
# Epoch 00044: saving model to model_init_2019-06-2305_11_09.891400/model-00044-9.84153-0.93514-10.61936-0.64000.h5
# Epoch 45/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.2021 - categorical_accuracy: 0.8971 - val_loss: 10.6412 - val_categorical_accuracy: 0.6400
#
# Epoch 00045: saving model to model_init_2019-06-2305_11_09.891400/model-00045-9.88057-0.93967-10.64120-0.64000.h5
# Epoch 46/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.2046 - categorical_accuracy: 0.8851 - val_loss: 10.6349 - val_categorical_accuracy: 0.6500
#
# Epoch 00046: saving model to model_init_2019-06-2305_11_09.891400/model-00046-9.89927-0.92308-10.63491-0.65000.h5
# Epoch 47/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.9883 - categorical_accuracy: 0.9042 - val_loss: 10.6370 - val_categorical_accuracy: 0.6400
#
# Epoch 00047: saving model to model_init_2019-06-2305_11_09.891400/model-00047-9.80469-0.93514-10.63696-0.64000.h5
# Epoch 48/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.1968 - categorical_accuracy: 0.8833 - val_loss: 10.5931 - val_categorical_accuracy: 0.6500
#
# Epoch 00048: saving model to model_init_2019-06-2305_11_09.891400/model-00048-9.87540-0.92911-10.59315-0.65000.h5
# Epoch 49/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.0358 - categorical_accuracy: 0.8995 - val_loss: 10.5703 - val_categorical_accuracy: 0.6400
#
# Epoch 00049: saving model to model_init_2019-06-2305_11_09.891400/model-00049-9.82548-0.93816-10.57028-0.64000.h5
# Epoch 50/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.8753 - categorical_accuracy: 0.9175 - val_loss: 10.5660 - val_categorical_accuracy: 0.6700
#
# Epoch 00050: saving model to model_init_2019-06-2305_11_09.891400/model-00050-9.77727-0.94118-10.56595-0.67000.h5
# Epoch 51/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.9844 - categorical_accuracy: 0.9262 - val_loss: 10.5724 - val_categorical_accuracy: 0.6500
#
# Epoch 00051: saving model to model_init_2019-06-2305_11_09.891400/model-00051-9.77299-0.96229-10.57243-0.65000.h5
# Epoch 52/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.0256 - categorical_accuracy: 0.9081 - val_loss: 10.5677 - val_categorical_accuracy: 0.6400
#
# Epoch 00052: saving model to model_init_2019-06-2305_11_09.891400/model-00052-9.78471-0.94721-10.56772-0.64000.h5
# Epoch 53/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.1139 - categorical_accuracy: 0.8785 - val_loss: 10.5559 - val_categorical_accuracy: 0.6600
#
# Epoch 00053: saving model to model_init_2019-06-2305_11_09.891400/model-00053-9.83794-0.92006-10.55586-0.66000.h5
# Epoch 54/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.9789 - categorical_accuracy: 0.9104 - val_loss: 10.5431 - val_categorical_accuracy: 0.6500
#
# Epoch 00054: saving model to model_init_2019-06-2305_11_09.891400/model-00054-9.78337-0.94570-10.54313-0.65000.h5
# Epoch 55/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.0777 - categorical_accuracy: 0.8909 - val_loss: 10.5291 - val_categorical_accuracy: 0.6400
#
# Epoch 00055: saving model to model_init_2019-06-2305_11_09.891400/model-00055-9.81520-0.92911-10.52912-0.64000.h5
# Epoch 56/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.0743 - categorical_accuracy: 0.8775 - val_loss: 10.5213 - val_categorical_accuracy: 0.6600
#
# Epoch 00056: saving model to model_init_2019-06-2305_11_09.891400/model-00056-9.81391-0.92308-10.52132-0.66000.h5
# Epoch 57/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.0759 - categorical_accuracy: 0.8966 - val_loss: 10.5131 - val_categorical_accuracy: 0.6600
#
# Epoch 00057: saving model to model_init_2019-06-2305_11_09.891400/model-00057-9.79470-0.93514-10.51314-0.66000.h5
# Epoch 58/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.0331 - categorical_accuracy: 0.9176 - val_loss: 10.5264 - val_categorical_accuracy: 0.6600
#
# Epoch 00058: saving model to model_init_2019-06-2305_11_09.891400/model-00058-9.77542-0.95324-10.52639-0.66000.h5
# Epoch 59/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.0529 - categorical_accuracy: 0.9090 - val_loss: 10.5355 - val_categorical_accuracy: 0.6400
#
# Epoch 00059: saving model to model_init_2019-06-2305_11_09.891400/model-00059-9.78573-0.94419-10.53545-0.64000.h5
# Epoch 60/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.9338 - categorical_accuracy: 0.9004 - val_loss: 10.5514 - val_categorical_accuracy: 0.6300
#
# Epoch 00060: saving model to model_init_2019-06-2305_11_09.891400/model-00060-9.74449-0.93514-10.55137-0.63000.h5
# Epoch 61/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.0401 - categorical_accuracy: 0.8937 - val_loss: 10.5047 - val_categorical_accuracy: 0.6100
#
# Epoch 00061: saving model to model_init_2019-06-2305_11_09.891400/model-00061-9.77403-0.93213-10.50466-0.61000.h5
# Epoch 62/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.0188 - categorical_accuracy: 0.8899 - val_loss: 10.5351 - val_categorical_accuracy: 0.6400
#
# Epoch 00062: saving model to model_init_2019-06-2305_11_09.891400/model-00062-9.76493-0.93213-10.53512-0.64000.h5
# Epoch 63/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.9293 - categorical_accuracy: 0.8985 - val_loss: 10.5183 - val_categorical_accuracy: 0.6700
#
# Epoch 00063: saving model to model_init_2019-06-2305_11_09.891400/model-00063-9.73740-0.94118-10.51833-0.67000.h5
# Epoch 64/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.9743 - categorical_accuracy: 0.8885 - val_loss: 10.4874 - val_categorical_accuracy: 0.6500
#
# Epoch 00064: saving model to model_init_2019-06-2305_11_09.891400/model-00064-9.75055-0.93062-10.48744-0.65000.h5
# Epoch 65/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.8969 - categorical_accuracy: 0.9152 - val_loss: 10.4971 - val_categorical_accuracy: 0.6300
#
# Epoch 00065: saving model to model_init_2019-06-2305_11_09.891400/model-00065-9.71988-0.94268-10.49709-0.63000.h5
# Epoch 66/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.0136 - categorical_accuracy: 0.9086 - val_loss: 10.4879 - val_categorical_accuracy: 0.6500
#
# Epoch 00066: saving model to model_init_2019-06-2305_11_09.891400/model-00066-9.72420-0.95173-10.48792-0.65000.h5
# Epoch 67/100
# 14/14 [==============================] - 37s 3s/step - loss: 10.0058 - categorical_accuracy: 0.9133 - val_loss: 10.4882 - val_categorical_accuracy: 0.6300
#
# Epoch 00067: saving model to model_init_2019-06-2305_11_09.891400/model-00067-9.73498-0.94872-10.48819-0.63000.h5
# Epoch 68/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.8822 - categorical_accuracy: 0.9162 - val_loss: 10.4779 - val_categorical_accuracy: 0.6600
#
# Epoch 00068: saving model to model_init_2019-06-2305_11_09.891400/model-00068-9.67453-0.95173-10.47787-0.66000.h5
# Epoch 69/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.8917 - categorical_accuracy: 0.9071 - val_loss: 10.4655 - val_categorical_accuracy: 0.6400
#
# Epoch 00069: saving model to model_init_2019-06-2305_11_09.891400/model-00069-9.67907-0.95023-10.46545-0.64000.h5
# Epoch 70/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.8157 - categorical_accuracy: 0.9167 - val_loss: 10.4518 - val_categorical_accuracy: 0.6400
#
# Epoch 00070: saving model to model_init_2019-06-2305_11_09.891400/model-00070-9.64573-0.95626-10.45177-0.64000.h5
# Epoch 71/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.8081 - categorical_accuracy: 0.9180 - val_loss: 10.4656 - val_categorical_accuracy: 0.6700
#
# Epoch 00071: saving model to model_init_2019-06-2305_11_09.891400/model-00071-9.65350-0.94570-10.46564-0.67000.h5
# Epoch 72/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.9374 - categorical_accuracy: 0.9081 - val_loss: 10.4591 - val_categorical_accuracy: 0.6600
#
# Epoch 00072: saving model to model_init_2019-06-2305_11_09.891400/model-00072-9.68441-0.94721-10.45906-0.66000.h5
# Epoch 73/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.9078 - categorical_accuracy: 0.9014 - val_loss: 10.4334 - val_categorical_accuracy: 0.6500
#
# Epoch 00073: saving model to model_init_2019-06-2305_11_09.891400/model-00073-9.66710-0.94419-10.43336-0.65000.h5
# Epoch 74/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.8203 - categorical_accuracy: 0.9099 - val_loss: 10.3829 - val_categorical_accuracy: 0.6500
#
# Epoch 00074: saving model to model_init_2019-06-2305_11_09.891400/model-00074-9.64676-0.94118-10.38286-0.65000.h5
# Epoch 75/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.8831 - categorical_accuracy: 0.9329 - val_loss: 10.3787 - val_categorical_accuracy: 0.6700
#
# Epoch 00075: saving model to model_init_2019-06-2305_11_09.891400/model-00075-9.64520-0.96531-10.37868-0.67000.h5
# Epoch 76/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.9161 - categorical_accuracy: 0.9267 - val_loss: 10.3698 - val_categorical_accuracy: 0.6500
#
# Epoch 00076: saving model to model_init_2019-06-2305_11_09.891400/model-00076-9.64185-0.96682-10.36984-0.65000.h5
# Epoch 77/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.8814 - categorical_accuracy: 0.9124 - val_loss: 10.3388 - val_categorical_accuracy: 0.6900
#
# Epoch 00077: saving model to model_init_2019-06-2305_11_09.891400/model-00077-9.63013-0.95173-10.33876-0.69000.h5
# Epoch 78/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.8293 - categorical_accuracy: 0.9128 - val_loss: 10.3298 - val_categorical_accuracy: 0.6900
#
# Epoch 00078: saving model to model_init_2019-06-2305_11_09.891400/model-00078-9.63140-0.94419-10.32984-0.69000.h5
# Epoch 79/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.8969 - categorical_accuracy: 0.9224 - val_loss: 10.3708 - val_categorical_accuracy: 0.6400
#
# Epoch 00079: saving model to model_init_2019-06-2305_11_09.891400/model-00079-9.63137-0.96229-10.37082-0.64000.h5
# Epoch 80/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.9524 - categorical_accuracy: 0.9152 - val_loss: 10.3432 - val_categorical_accuracy: 0.6600
#
# Epoch 00080: saving model to model_init_2019-06-2305_11_09.891400/model-00080-9.66086-0.95475-10.34323-0.66000.h5
# Epoch 81/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.9173 - categorical_accuracy: 0.8995 - val_loss: 10.3492 - val_categorical_accuracy: 0.6600
#
# Epoch 00081: saving model to model_init_2019-06-2305_11_09.891400/model-00081-9.65663-0.93816-10.34921-0.66000.h5
# Epoch 82/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.8345 - categorical_accuracy: 0.9152 - val_loss: 10.3438 - val_categorical_accuracy: 0.6700
#
# Epoch 00082: saving model to model_init_2019-06-2305_11_09.891400/model-00082-9.58480-0.95475-10.34377-0.67000.h5
# Epoch 83/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.7842 - categorical_accuracy: 0.9248 - val_loss: 10.3212 - val_categorical_accuracy: 0.7000
#
# Epoch 00083: saving model to model_init_2019-06-2305_11_09.891400/model-00083-9.57841-0.96078-10.32125-0.70000.h5
# Epoch 84/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.7716 - categorical_accuracy: 0.9300 - val_loss: 10.3384 - val_categorical_accuracy: 0.7000
#
# Epoch 00084: saving model to model_init_2019-06-2305_11_09.891400/model-00084-9.57077-0.96229-10.33842-0.70000.h5
# Epoch 85/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.8734 - categorical_accuracy: 0.9195 - val_loss: 10.3377 - val_categorical_accuracy: 0.6800
#
# Epoch 00085: saving model to model_init_2019-06-2305_11_09.891400/model-00085-9.59489-0.95928-10.33766-0.68000.h5
# Epoch 86/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.9083 - categorical_accuracy: 0.9057 - val_loss: 10.3036 - val_categorical_accuracy: 0.6900
#
# Epoch 00086: saving model to model_init_2019-06-2305_11_09.891400/model-00086-9.60213-0.94872-10.30360-0.69000.h5
# Epoch 87/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.7487 - categorical_accuracy: 0.9261 - val_loss: 10.2854 - val_categorical_accuracy: 0.6800
#
# Epoch 00087: saving model to model_init_2019-06-2305_11_09.891400/model-00087-9.58487-0.95023-10.28542-0.68000.h5
# Epoch 88/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.8797 - categorical_accuracy: 0.9114 - val_loss: 10.2812 - val_categorical_accuracy: 0.7000
#
# Epoch 00088: saving model to model_init_2019-06-2305_11_09.891400/model-00088-9.57995-0.95475-10.28125-0.70000.h5
# Epoch 89/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.7876 - categorical_accuracy: 0.9152 - val_loss: 10.2849 - val_categorical_accuracy: 0.6900
#
# Epoch 00089: saving model to model_init_2019-06-2305_11_09.891400/model-00089-9.56089-0.95475-10.28494-0.69000.h5
# Epoch 90/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.6796 - categorical_accuracy: 0.9314 - val_loss: 10.2819 - val_categorical_accuracy: 0.7000
#
# Epoch 00090: saving model to model_init_2019-06-2305_11_09.891400/model-00090-9.52579-0.96380-10.28187-0.70000.h5
# Epoch 91/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.7106 - categorical_accuracy: 0.9333 - val_loss: 10.2775 - val_categorical_accuracy: 0.6900
#
# Epoch 00091: saving model to model_init_2019-06-2305_11_09.891400/model-00091-9.52366-0.95777-10.27746-0.69000.h5
# Epoch 92/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.7095 - categorical_accuracy: 0.9200 - val_loss: 10.2698 - val_categorical_accuracy: 0.7000
#
# Epoch 00092: saving model to model_init_2019-06-2305_11_09.891400/model-00092-9.52598-0.95173-10.26980-0.70000.h5
# Epoch 93/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.7411 - categorical_accuracy: 0.9109 - val_loss: 10.2607 - val_categorical_accuracy: 0.7000
#
# Epoch 00093: saving model to model_init_2019-06-2305_11_09.891400/model-00093-9.53906-0.95023-10.26068-0.70000.h5
# Epoch 94/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.6568 - categorical_accuracy: 0.9271 - val_loss: 10.2673 - val_categorical_accuracy: 0.7000
#
# Epoch 00094: saving model to model_init_2019-06-2305_11_09.891400/model-00094-9.49937-0.95928-10.26732-0.70000.h5
# Epoch 95/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.8862 - categorical_accuracy: 0.9157 - val_loss: 10.2092 - val_categorical_accuracy: 0.7000
#
# Epoch 00095: saving model to model_init_2019-06-2305_11_09.891400/model-00095-9.56830-0.95928-10.20921-0.70000.h5
# Epoch 96/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.7244 - categorical_accuracy: 0.9205 - val_loss: 10.1864 - val_categorical_accuracy: 0.7200
#
# Epoch 00096: saving model to model_init_2019-06-2305_11_09.891400/model-00096-9.50744-0.95626-10.18640-0.72000.h5
# Epoch 97/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.5762 - categorical_accuracy: 0.9257 - val_loss: 10.1797 - val_categorical_accuracy: 0.7100
#
# Epoch 00097: saving model to model_init_2019-06-2305_11_09.891400/model-00097-9.46723-0.95777-10.17972-0.71000.h5
# Epoch 98/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.7607 - categorical_accuracy: 0.9233 - val_loss: 10.1829 - val_categorical_accuracy: 0.7000
#
# Epoch 00098: saving model to model_init_2019-06-2305_11_09.891400/model-00098-9.52254-0.95928-10.18291-0.70000.h5
# Epoch 99/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.7582 - categorical_accuracy: 0.9233 - val_loss: 10.1893 - val_categorical_accuracy: 0.7200
#
# Epoch 00099: saving model to model_init_2019-06-2305_11_09.891400/model-00099-9.51977-0.95928-10.18928-0.72000.h5
# Epoch 100/100
# 14/14 [==============================] - 37s 3s/step - loss: 9.8643 - categorical_accuracy: 0.9119 - val_loss: 10.1757 - val_categorical_accuracy: 0.7100
#
# Epoch 00100: saving model to model_init_2019-06-2305_11_09.891400/model-00100-9.56205-0.94721-10.17568-0.71000.h5

# %% [markdown]
# ### The best accuracy values of the Conv3D model were received in Epoch# 99
# #### Training accuracy --> 0.95928
# #### Validation accuracy --> 0.7200

# %% [markdown]
# ## CNN - RNN Model
#
# ### We are using ResNet50 model layers to leverage transfer learning in 2DCNN layers. These layers are stacked with a GRU layer to complete the CNN-RNN architecture.

# %%
batch_size = 40

# %% [markdown]
# ## Generator
#
# ### We need to write a different generator function (generator_2) as the input image size for ResNet50 is (224, 224, 3)

# %%
def generator_2(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = [0,2,6,9,12,15,18,21,24,27] #create a list of image numbers you want to use for a particular video
    while True:
        t = np.random.permutation(folder_list)
        num_sequences = len(folder_list)
        num_batches = int(num_sequences/batch_size) # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,10,224,224,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    if(image.shape[0] == 360 and image.shape[1] == 360): # Resize the 360X360 image to 224X224
                        image = imresize(image, (224, 224)) 
                    else:
                        image = image[:,20:140] # First crop the 120X160 image to 120X120
                        image = imresize(image, (224, 224)) # Now resize the 120X120 image to 224X224
                    
                    batch_data[folder,idx] = image
                    
                    batch_data[folder,idx,:,:,0] = batch_data[folder,idx,:,:,0] - (np.min(batch_data[folder,idx,:,:,0])/
                                                    np.max(batch_data[folder,idx,:,:,0]) - np.min(batch_data[folder,idx,:,:,0]))
                    batch_data[folder,idx,:,:,1] = batch_data[folder,idx,:,:,1] - (np.min(batch_data[folder,idx,:,:,1])/
                                                    np.max(batch_data[folder,idx,:,:,1]) - np.min(batch_data[folder,idx,:,:,1]))
                    batch_data[folder,idx,:,:,2] = batch_data[folder,idx,:,:,2] - (np.min(batch_data[folder,idx,:,:,2])/
                                                    np.max(batch_data[folder,idx,:,:,2]) - np.min(batch_data[folder,idx,:,:,2]))
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches
        remaining_steps = num_sequences%batch_size
        
        if (remaining_steps) > 0:
            batch_data = np.zeros((remaining_steps,10,224,224,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((remaining_steps,5)) # batch_labels is the one hot representation of the output
            for folder in range(remaining_steps): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (num_batches*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    if(image.shape[0] == 360 and image.shape[1] == 360): # Resize the 360X360 image to 224X224
                        image = imresize(image, (224, 224))
                    else:
                        image = image[:,20:140] # First crop the 120X160 image to 120X120
                        image = imresize(image, (224, 224)) # Now resize the 120X120 image to 224X224
                    
                    batch_data[folder,idx] = image
                    
                    batch_data[folder,idx,:,:,0] = batch_data[folder,idx,:,:,0] - (np.min(batch_data[folder,idx,:,:,0])/
                                                    np.max(batch_data[folder,idx,:,:,0]) - np.min(batch_data[folder,idx,:,:,0]))
                    batch_data[folder,idx,:,:,1] = batch_data[folder,idx,:,:,1] - (np.min(batch_data[folder,idx,:,:,1])/
                                                    np.max(batch_data[folder,idx,:,:,1]) - np.min(batch_data[folder,idx,:,:,1]))
                    batch_data[folder,idx,:,:,2] = batch_data[folder,idx,:,:,2] - (np.min(batch_data[folder,idx,:,:,2])/
                                                    np.max(batch_data[folder,idx,:,:,2]) - np.min(batch_data[folder,idx,:,:,2]))
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %%
curr_dt_time = datetime.datetime.now()
train_path = './Project_data/train'
val_path = './Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 100 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 100

# %% [markdown]
# ## Model

# %%
from keras.applications import ResNet50
from keras.applications.resnet50 import preprocess_input
from keras.layers import GlobalAveragePooling2D
from keras.layers import Dense, Dropout, Flatten
from keras.models import Model
from keras.layers import TimeDistributed
from keras.layers import GRU
from keras.layers import Input, Reshape

#write your model here

# Get base model: ResNet50 
base_model = ResNet50(weights='imagenet', include_top=False)

# training the model after 140 layers. Freezing first 140 layers
split_at = 140
for layer in base_model.layers[:split_at]: layer.trainable = False
for layer in base_model.layers[split_at:]: layer.trainable = True

# Get the output from the base model 
base_model_ouput = base_model.output

# Adding our own layers at the end
# global average pooling: computes the average of all values in the feature map
x = GlobalAveragePooling2D()(base_model_ouput)

# fully connected layer
x = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(x)

resnet_model = Model(inputs=base_model.input, outputs=x)

# %%
frames = Input(shape=(10, 224, 224, 3))
x = TimeDistributed(resnet_model)(frames)
x = TimeDistributed(Flatten())(x)

x = GRU(64, return_sequences=False)(x)

x = Dense(5, activation='softmax')(x)

gru_model = Model(inputs=frames, outputs=x)

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = optimizers.SGD()#write your optimizer
gru_model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (gru_model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 10, 224, 224, 3)   0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 10, 512)           24636800
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 10, 512)           0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 64)                110784
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 24,747,909
# Trainable params: 16,136,197
# Non-trainable params: 8,611,712
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator_2(train_path, train_doc, batch_size)
val_generator = generator_2(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=5, min_lr=0.001)# write the REducelronplateau code here

callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
gru_model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  ./Project_data/val ; batch size = 40
# Source path =  ./Project_data/train ; batch size = 40
# Epoch 1/100
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:47: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:53: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:56: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 17/17 [==============================] - 137s 8s/step - loss: 9.7056 - categorical_accuracy: 0.3855 - val_loss: 9.7585 - val_categorical_accuracy: 0.2900
#
# Epoch 00001: saving model to model_init_2019-06-2318_25_41.949303/model-00001-9.70349-0.39065-9.75852-0.29000.h5
# Epoch 2/100
# 17/17 [==============================] - 80s 5s/step - loss: 9.0930 - categorical_accuracy: 0.6505 - val_loss: 9.5111 - val_categorical_accuracy: 0.4200
#
# Epoch 00002: saving model to model_init_2019-06-2318_25_41.949303/model-00002-9.05362-0.66516-9.51111-0.42000.h5
# Epoch 3/100
# 17/17 [==============================] - 76s 4s/step - loss: 8.7882 - categorical_accuracy: 0.7923 - val_loss: 9.4291 - val_categorical_accuracy: 0.4800
#
# Epoch 00003: saving model to model_init_2019-06-2318_25_41.949303/model-00003-8.73286-0.81146-9.42912-0.48000.h5
# Epoch 4/100
# 17/17 [==============================] - 76s 4s/step - loss: 8.6311 - categorical_accuracy: 0.8425 - val_loss: 9.8427 - val_categorical_accuracy: 0.1700
#
# Epoch 00004: saving model to model_init_2019-06-2318_25_41.949303/model-00004-8.56517-0.85973-9.84270-0.17000.h5
# Epoch 5/100
# 17/17 [==============================] - 75s 4s/step - loss: 8.5017 - categorical_accuracy: 0.8759 - val_loss: 8.9723 - val_categorical_accuracy: 0.7000
#
# Epoch 00005: saving model to model_init_2019-06-2318_25_41.949303/model-00005-8.44673-0.89291-8.97231-0.70000.h5
# Epoch 6/100
# 17/17 [==============================] - 76s 4s/step - loss: 8.3616 - categorical_accuracy: 0.9167 - val_loss: 9.3751 - val_categorical_accuracy: 0.4900
#
# Epoch 00006: saving model to model_init_2019-06-2318_25_41.949303/model-00006-8.28634-0.93363-9.37506-0.49000.h5
# Epoch 7/100
# 17/17 [==============================] - 76s 4s/step - loss: 8.3330 - categorical_accuracy: 0.9048 - val_loss: 8.9953 - val_categorical_accuracy: 0.5200
#
# Epoch 00007: saving model to model_init_2019-06-2318_25_41.949303/model-00007-8.24758-0.92459-8.99527-0.52000.h5
# Epoch 8/100
# 17/17 [==============================] - 75s 4s/step - loss: 8.1539 - categorical_accuracy: 0.9366 - val_loss: 9.1375 - val_categorical_accuracy: 0.5300
#
# Epoch 00008: saving model to model_init_2019-06-2318_25_41.949303/model-00008-8.10770-0.94872-9.13748-0.53000.h5
# Epoch 9/100
# 17/17 [==============================] - 75s 4s/step - loss: 8.1937 - categorical_accuracy: 0.8974 - val_loss: 8.7664 - val_categorical_accuracy: 0.6900
#
# Epoch 00009: saving model to model_init_2019-06-2318_25_41.949303/model-00009-8.10675-0.91704-8.76644-0.69000.h5
# Epoch 10/100
# 17/17 [==============================] - 75s 4s/step - loss: 8.0343 - categorical_accuracy: 0.9493 - val_loss: 8.9966 - val_categorical_accuracy: 0.5700
#
# Epoch 00010: saving model to model_init_2019-06-2318_25_41.949303/model-00010-7.97928-0.96380-8.99662-0.57000.h5
# Epoch 11/100
# 17/17 [==============================] - 75s 4s/step - loss: 8.0442 - categorical_accuracy: 0.9049 - val_loss: 8.9310 - val_categorical_accuracy: 0.5400
#
# Epoch 00011: saving model to model_init_2019-06-2318_25_41.949303/model-00011-7.97492-0.92157-8.93095-0.54000.h5
# Epoch 12/100
# 17/17 [==============================] - 75s 4s/step - loss: 8.0259 - categorical_accuracy: 0.9098 - val_loss: 8.6921 - val_categorical_accuracy: 0.6300
#
# Epoch 00012: saving model to model_init_2019-06-2318_25_41.949303/model-00012-7.93829-0.92760-8.69206-0.63000.h5
# Epoch 13/100
# 17/17 [==============================] - 76s 4s/step - loss: 7.9081 - categorical_accuracy: 0.9506 - val_loss: 8.9178 - val_categorical_accuracy: 0.5600
#
# Epoch 00013: saving model to model_init_2019-06-2318_25_41.949303/model-00013-7.83339-0.96833-8.91782-0.56000.h5
# Epoch 14/100
# 17/17 [==============================] - 75s 4s/step - loss: 7.8912 - categorical_accuracy: 0.9241 - val_loss: 8.7964 - val_categorical_accuracy: 0.5800
#
# Epoch 00014: saving model to model_init_2019-06-2318_25_41.949303/model-00014-7.82136-0.94118-8.79637-0.58000.h5
# Epoch 15/100
# 17/17 [==============================] - 75s 4s/step - loss: 7.7953 - categorical_accuracy: 0.9428 - val_loss: 8.4367 - val_categorical_accuracy: 0.6700
#
# Epoch 00015: saving model to model_init_2019-06-2318_25_41.949303/model-00015-7.71438-0.95928-8.43667-0.67000.h5
# Epoch 16/100
# 17/17 [==============================] - 75s 4s/step - loss: 7.7174 - categorical_accuracy: 0.9496 - val_loss: 8.3429 - val_categorical_accuracy: 0.7100
#
# Epoch 00016: saving model to model_init_2019-06-2318_25_41.949303/model-00016-7.63590-0.96833-8.34288-0.71000.h5
# Epoch 17/100
# 17/17 [==============================] - 75s 4s/step - loss: 7.6880 - categorical_accuracy: 0.9481 - val_loss: 8.3061 - val_categorical_accuracy: 0.6100
#
# Epoch 00017: saving model to model_init_2019-06-2318_25_41.949303/model-00017-7.60384-0.96682-8.30606-0.61000.h5
# Epoch 18/100
# 17/17 [==============================] - 76s 4s/step - loss: 7.6458 - categorical_accuracy: 0.9310 - val_loss: 8.1494 - val_categorical_accuracy: 0.7000
#
# Epoch 00018: saving model to model_init_2019-06-2318_25_41.949303/model-00018-7.57715-0.94721-8.14942-0.70000.h5
# Epoch 19/100
# 17/17 [==============================] - 75s 4s/step - loss: 7.6066 - categorical_accuracy: 0.9412 - val_loss: 8.4391 - val_categorical_accuracy: 0.6000
#
# Epoch 00019: saving model to model_init_2019-06-2318_25_41.949303/model-00019-7.51632-0.96078-8.43906-0.60000.h5
# Epoch 20/100
# 17/17 [==============================] - 75s 4s/step - loss: 7.5383 - categorical_accuracy: 0.9398 - val_loss: 9.1953 - val_categorical_accuracy: 0.3600
#
# Epoch 00020: saving model to model_init_2019-06-2318_25_41.949303/model-00020-7.47085-0.95626-9.19534-0.36000.h5
# Epoch 21/100
# 17/17 [==============================] - 76s 4s/step - loss: 7.5855 - categorical_accuracy: 0.9039 - val_loss: 8.2667 - val_categorical_accuracy: 0.6200
#
# Epoch 00021: saving model to model_init_2019-06-2318_25_41.949303/model-00021-7.51500-0.92157-8.26668-0.62000.h5
# Epoch 22/100
# 17/17 [==============================] - 76s 4s/step - loss: 7.4211 - categorical_accuracy: 0.9487 - val_loss: 8.0386 - val_categorical_accuracy: 0.7400
#
# Epoch 00022: saving model to model_init_2019-06-2318_25_41.949303/model-00022-7.34179-0.96531-8.03858-0.74000.h5
# Epoch 23/100
# 17/17 [==============================] - 76s 4s/step - loss: 7.3993 - categorical_accuracy: 0.9407 - val_loss: 8.1375 - val_categorical_accuracy: 0.5800
#
# Epoch 00023: saving model to model_init_2019-06-2318_25_41.949303/model-00023-7.30772-0.95928-8.13752-0.58000.h5
# Epoch 24/100
# 17/17 [==============================] - 76s 4s/step - loss: 7.3599 - categorical_accuracy: 0.9407 - val_loss: 8.4479 - val_categorical_accuracy: 0.5200
#
# Epoch 00024: saving model to model_init_2019-06-2318_25_41.949303/model-00024-7.27689-0.95928-8.44785-0.52000.h5
# Epoch 25/100
# 17/17 [==============================] - 76s 4s/step - loss: 7.3042 - categorical_accuracy: 0.9422 - val_loss: 8.0234 - val_categorical_accuracy: 0.6900
#
# Epoch 00025: saving model to model_init_2019-06-2318_25_41.949303/model-00025-7.21830-0.96078-8.02340-0.69000.h5
# Epoch 26/100
# 17/17 [==============================] - 76s 4s/step - loss: 7.1940 - categorical_accuracy: 0.9562 - val_loss: 8.1764 - val_categorical_accuracy: 0.6100
#
# Epoch 00026: saving model to model_init_2019-06-2318_25_41.949303/model-00026-7.13103-0.96983-8.17636-0.61000.h5
# Epoch 27/100
# 17/17 [==============================] - 76s 4s/step - loss: 7.2610 - categorical_accuracy: 0.9195 - val_loss: 8.0153 - val_categorical_accuracy: 0.6300
#
# Epoch 00027: saving model to model_init_2019-06-2318_25_41.949303/model-00027-7.16838-0.93967-8.01528-0.63000.h5
# Epoch 28/100
# 17/17 [==============================] - 76s 4s/step - loss: 7.1692 - categorical_accuracy: 0.9471 - val_loss: 7.9310 - val_categorical_accuracy: 0.6400
#
# Epoch 00028: saving model to model_init_2019-06-2318_25_41.949303/model-00028-7.07574-0.96682-7.93102-0.64000.h5
# Epoch 29/100
# 17/17 [==============================] - 76s 4s/step - loss: 7.0699 - categorical_accuracy: 0.9541 - val_loss: 7.6946 - val_categorical_accuracy: 0.7000
#
# Epoch 00029: saving model to model_init_2019-06-2318_25_41.949303/model-00029-6.99787-0.96983-7.69460-0.70000.h5
# Epoch 30/100
# 17/17 [==============================] - 76s 4s/step - loss: 7.0175 - categorical_accuracy: 0.9550 - val_loss: 8.3289 - val_categorical_accuracy: 0.4600
#
# Epoch 00030: saving model to model_init_2019-06-2318_25_41.949303/model-00030-6.94128-0.97285-8.32893-0.46000.h5
# Epoch 31/100
# 17/17 [==============================] - 76s 4s/step - loss: 7.1326 - categorical_accuracy: 0.9245 - val_loss: 7.9522 - val_categorical_accuracy: 0.5700
#
# Epoch 00031: saving model to model_init_2019-06-2318_25_41.949303/model-00031-7.03863-0.94268-7.95223-0.57000.h5
# Epoch 32/100
# 17/17 [==============================] - 76s 4s/step - loss: 6.9363 - categorical_accuracy: 0.9478 - val_loss: 7.6536 - val_categorical_accuracy: 0.6300
#
# Epoch 00032: saving model to model_init_2019-06-2318_25_41.949303/model-00032-6.87620-0.96229-7.65358-0.63000.h5
# Epoch 33/100
# 17/17 [==============================] - 76s 4s/step - loss: 6.9293 - categorical_accuracy: 0.9466 - val_loss: 7.6556 - val_categorical_accuracy: 0.6900
#
# Epoch 00033: saving model to model_init_2019-06-2318_25_41.949303/model-00033-6.83672-0.96531-7.65564-0.69000.h5
# Epoch 34/100
# 17/17 [==============================] - 76s 4s/step - loss: 6.8432 - categorical_accuracy: 0.9556 - val_loss: 7.7549 - val_categorical_accuracy: 0.6400
#
# Epoch 00034: saving model to model_init_2019-06-2318_25_41.949303/model-00034-6.77013-0.97134-7.75485-0.64000.h5
# Epoch 35/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.8626 - categorical_accuracy: 0.9402 - val_loss: 7.5694 - val_categorical_accuracy: 0.6600
#
# Epoch 00035: saving model to model_init_2019-06-2318_25_41.949303/model-00035-6.76335-0.96078-7.56938-0.66000.h5
# Epoch 36/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.7531 - categorical_accuracy: 0.9477 - val_loss: 7.4235 - val_categorical_accuracy: 0.7000
#
# Epoch 00036: saving model to model_init_2019-06-2318_25_41.949303/model-00036-6.67802-0.96531-7.42347-0.70000.h5
# Epoch 37/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.7387 - categorical_accuracy: 0.9485 - val_loss: 7.5021 - val_categorical_accuracy: 0.5900
#
# Epoch 00037: saving model to model_init_2019-06-2318_25_41.949303/model-00037-6.64416-0.96833-7.50206-0.59000.h5
# Epoch 38/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.7183 - categorical_accuracy: 0.9363 - val_loss: 7.5810 - val_categorical_accuracy: 0.6900
#
# Epoch 00038: saving model to model_init_2019-06-2318_25_41.949303/model-00038-6.63685-0.95475-7.58100-0.69000.h5
# Epoch 39/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.6549 - categorical_accuracy: 0.9435 - val_loss: 7.2051 - val_categorical_accuracy: 0.7500
#
# Epoch 00039: saving model to model_init_2019-06-2318_25_41.949303/model-00039-6.56182-0.96531-7.20507-0.75000.h5
# Epoch 40/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.5627 - categorical_accuracy: 0.9571 - val_loss: 7.2782 - val_categorical_accuracy: 0.7600
#
# Epoch 00040: saving model to model_init_2019-06-2318_25_41.949303/model-00040-6.49408-0.97285-7.27824-0.76000.h5
# Epoch 41/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.5518 - categorical_accuracy: 0.9496 - val_loss: 7.4680 - val_categorical_accuracy: 0.5900
#
# Epoch 00041: saving model to model_init_2019-06-2318_25_41.949303/model-00041-6.46881-0.96833-7.46801-0.59000.h5
# Epoch 42/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.5386 - categorical_accuracy: 0.9373 - val_loss: 7.2682 - val_categorical_accuracy: 0.7300
#
# Epoch 00042: saving model to model_init_2019-06-2318_25_41.949303/model-00042-6.45311-0.95475-7.26820-0.73000.h5
# Epoch 43/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.5101 - categorical_accuracy: 0.9437 - val_loss: 7.0931 - val_categorical_accuracy: 0.7000
#
# Epoch 00043: saving model to model_init_2019-06-2318_25_41.949303/model-00043-6.41758-0.96229-7.09309-0.70000.h5
# Epoch 44/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.3738 - categorical_accuracy: 0.9600 - val_loss: 7.7059 - val_categorical_accuracy: 0.5500
#
# Epoch 00044: saving model to model_init_2019-06-2318_25_41.949303/model-00044-6.30647-0.97587-7.70588-0.55000.h5
# Epoch 45/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.4281 - categorical_accuracy: 0.9323 - val_loss: 6.8746 - val_categorical_accuracy: 0.7500
#
# Epoch 00045: saving model to model_init_2019-06-2318_25_41.949303/model-00045-6.33907-0.95173-6.87456-0.75000.h5
# Epoch 46/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.3285 - categorical_accuracy: 0.9535 - val_loss: 7.6560 - val_categorical_accuracy: 0.5500
#
# Epoch 00046: saving model to model_init_2019-06-2318_25_41.949303/model-00046-6.24833-0.97134-7.65602-0.55000.h5
# Epoch 47/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.3235 - categorical_accuracy: 0.9422 - val_loss: 6.9362 - val_categorical_accuracy: 0.7200
#
# Epoch 00047: saving model to model_init_2019-06-2318_25_41.949303/model-00047-6.23335-0.96078-6.93617-0.72000.h5
# Epoch 48/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.2635 - categorical_accuracy: 0.9491 - val_loss: 7.0479 - val_categorical_accuracy: 0.6800
#
# Epoch 00048: saving model to model_init_2019-06-2318_25_41.949303/model-00048-6.18224-0.96682-7.04789-0.68000.h5
# Epoch 49/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.2463 - categorical_accuracy: 0.9416 - val_loss: 7.1726 - val_categorical_accuracy: 0.6300
#
# Epoch 00049: saving model to model_init_2019-06-2318_25_41.949303/model-00049-6.15212-0.96229-7.17263-0.63000.h5
# Epoch 50/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.2129 - categorical_accuracy: 0.9406 - val_loss: 7.0158 - val_categorical_accuracy: 0.7000
#
# Epoch 00050: saving model to model_init_2019-06-2318_25_41.949303/model-00050-6.11818-0.96229-7.01582-0.70000.h5
# Epoch 51/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.1608 - categorical_accuracy: 0.9550 - val_loss: 6.8054 - val_categorical_accuracy: 0.7200
#
# Epoch 00051: saving model to model_init_2019-06-2318_25_41.949303/model-00051-6.09116-0.97285-6.80543-0.72000.h5
# Epoch 52/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.1203 - categorical_accuracy: 0.9525 - val_loss: 6.9390 - val_categorical_accuracy: 0.7100
#
# Epoch 00052: saving model to model_init_2019-06-2318_25_41.949303/model-00052-6.05509-0.97134-6.93901-0.71000.h5
# Epoch 53/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.1468 - categorical_accuracy: 0.9525 - val_loss: 6.7712 - val_categorical_accuracy: 0.7700
#
# Epoch 00053: saving model to model_init_2019-06-2318_25_41.949303/model-00053-6.06540-0.97134-6.77120-0.77000.h5
# Epoch 54/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.0984 - categorical_accuracy: 0.9600 - val_loss: 6.8609 - val_categorical_accuracy: 0.7600
#
# Epoch 00054: saving model to model_init_2019-06-2318_25_41.949303/model-00054-6.03044-0.97587-6.86091-0.76000.h5
# Epoch 55/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.0831 - categorical_accuracy: 0.9600 - val_loss: 6.6092 - val_categorical_accuracy: 0.8000
#
# Epoch 00055: saving model to model_init_2019-06-2318_25_41.949303/model-00055-6.01667-0.97587-6.60919-0.80000.h5
# Epoch 56/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.0710 - categorical_accuracy: 0.9575 - val_loss: 6.6443 - val_categorical_accuracy: 0.8100
#
# Epoch 00056: saving model to model_init_2019-06-2318_25_41.949303/model-00056-6.00483-0.97436-6.64433-0.81000.h5
# Epoch 57/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.0774 - categorical_accuracy: 0.9575 - val_loss: 6.6083 - val_categorical_accuracy: 0.7800
#
# Epoch 00057: saving model to model_init_2019-06-2318_25_41.949303/model-00057-6.00546-0.97436-6.60829-0.78000.h5
# Epoch 58/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.0767 - categorical_accuracy: 0.9550 - val_loss: 6.6111 - val_categorical_accuracy: 0.7600
#
# Epoch 00058: saving model to model_init_2019-06-2318_25_41.949303/model-00058-6.00166-0.97285-6.61113-0.76000.h5
# Epoch 59/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.0595 - categorical_accuracy: 0.9575 - val_loss: 6.5569 - val_categorical_accuracy: 0.8000
#
# Epoch 00059: saving model to model_init_2019-06-2318_25_41.949303/model-00059-5.98961-0.97436-6.55691-0.80000.h5
# Epoch 60/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.0344 - categorical_accuracy: 0.9600 - val_loss: 6.6072 - val_categorical_accuracy: 0.7900
#
# Epoch 00060: saving model to model_init_2019-06-2318_25_41.949303/model-00060-5.97105-0.97587-6.60721-0.79000.h5
# Epoch 61/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.0421 - categorical_accuracy: 0.9575 - val_loss: 6.6698 - val_categorical_accuracy: 0.7700
#
# Epoch 00061: saving model to model_init_2019-06-2318_25_41.949303/model-00061-5.97143-0.97436-6.66981-0.77000.h5
# Epoch 62/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.0290 - categorical_accuracy: 0.9500 - val_loss: 6.7083 - val_categorical_accuracy: 0.7400
#
# Epoch 00062: saving model to model_init_2019-06-2318_25_41.949303/model-00062-5.95884-0.96983-6.70828-0.74000.h5
# Epoch 63/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.0625 - categorical_accuracy: 0.9525 - val_loss: 6.6559 - val_categorical_accuracy: 0.7800
#
# Epoch 00063: saving model to model_init_2019-06-2318_25_41.949303/model-00063-5.97679-0.97134-6.65591-0.78000.h5
# Epoch 64/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.0293 - categorical_accuracy: 0.9525 - val_loss: 6.6886 - val_categorical_accuracy: 0.7600
#
# Epoch 00064: saving model to model_init_2019-06-2318_25_41.949303/model-00064-5.95256-0.97134-6.68861-0.76000.h5
# Epoch 65/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.0167 - categorical_accuracy: 0.9575 - val_loss: 6.6542 - val_categorical_accuracy: 0.7500
#
# Epoch 00065: saving model to model_init_2019-06-2318_25_41.949303/model-00065-5.94525-0.97436-6.65419-0.75000.h5
# Epoch 66/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9918 - categorical_accuracy: 0.9625 - val_loss: 6.7535 - val_categorical_accuracy: 0.7600
#
# Epoch 00066: saving model to model_init_2019-06-2318_25_41.949303/model-00066-5.92888-0.97738-6.75348-0.76000.h5
# Epoch 67/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.0166 - categorical_accuracy: 0.9550 - val_loss: 6.7877 - val_categorical_accuracy: 0.7400
#
# Epoch 00067: saving model to model_init_2019-06-2318_25_41.949303/model-00067-5.94205-0.97285-6.78775-0.74000.h5
# Epoch 68/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.0141 - categorical_accuracy: 0.9550 - val_loss: 6.6317 - val_categorical_accuracy: 0.7600
#
# Epoch 00068: saving model to model_init_2019-06-2318_25_41.949303/model-00068-5.93865-0.97285-6.63175-0.76000.h5
# Epoch 69/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.0254 - categorical_accuracy: 0.9550 - val_loss: 6.6889 - val_categorical_accuracy: 0.7400
#
# Epoch 00069: saving model to model_init_2019-06-2318_25_41.949303/model-00069-5.94439-0.97285-6.68894-0.74000.h5
# Epoch 70/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.0141 - categorical_accuracy: 0.9500 - val_loss: 6.5632 - val_categorical_accuracy: 0.7600
#
# Epoch 00070: saving model to model_init_2019-06-2318_25_41.949303/model-00070-5.93637-0.96983-6.56316-0.76000.h5
# Epoch 71/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9872 - categorical_accuracy: 0.9575 - val_loss: 6.5943 - val_categorical_accuracy: 0.7600
#
# Epoch 00071: saving model to model_init_2019-06-2318_25_41.949303/model-00071-5.91816-0.97436-6.59428-0.76000.h5
# Epoch 72/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9628 - categorical_accuracy: 0.9600 - val_loss: 6.6790 - val_categorical_accuracy: 0.7400
#
# Epoch 00072: saving model to model_init_2019-06-2318_25_41.949303/model-00072-5.90132-0.97587-6.67899-0.74000.h5
# Epoch 73/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9955 - categorical_accuracy: 0.9550 - val_loss: 6.6545 - val_categorical_accuracy: 0.7500
#
# Epoch 00073: saving model to model_init_2019-06-2318_25_41.949303/model-00073-5.91997-0.97285-6.65453-0.75000.h5
# Epoch 74/100
# 17/17 [==============================] - 75s 4s/step - loss: 6.0036 - categorical_accuracy: 0.9525 - val_loss: 6.7023 - val_categorical_accuracy: 0.7600
#
# Epoch 00074: saving model to model_init_2019-06-2318_25_41.949303/model-00074-5.92192-0.97134-6.70235-0.76000.h5
# Epoch 75/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9676 - categorical_accuracy: 0.9550 - val_loss: 6.3660 - val_categorical_accuracy: 0.7900
#
# Epoch 00075: saving model to model_init_2019-06-2318_25_41.949303/model-00075-5.89917-0.97285-6.36602-0.79000.h5
# Epoch 76/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9937 - categorical_accuracy: 0.9525 - val_loss: 6.4423 - val_categorical_accuracy: 0.7800
#
# Epoch 00076: saving model to model_init_2019-06-2318_25_41.949303/model-00076-5.91454-0.97134-6.44233-0.78000.h5
# Epoch 77/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9940 - categorical_accuracy: 0.9500 - val_loss: 6.4304 - val_categorical_accuracy: 0.7900
#
# Epoch 00077: saving model to model_init_2019-06-2318_25_41.949303/model-00077-5.91247-0.96983-6.43037-0.79000.h5
# Epoch 78/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9772 - categorical_accuracy: 0.9550 - val_loss: 6.6412 - val_categorical_accuracy: 0.7700
#
# Epoch 00078: saving model to model_init_2019-06-2318_25_41.949303/model-00078-5.90145-0.97285-6.64117-0.77000.h5
# Epoch 79/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9813 - categorical_accuracy: 0.9550 - val_loss: 6.5939 - val_categorical_accuracy: 0.7700
#
# Epoch 00079: saving model to model_init_2019-06-2318_25_41.949303/model-00079-5.90175-0.97285-6.59390-0.77000.h5
# Epoch 80/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9540 - categorical_accuracy: 0.9550 - val_loss: 6.4862 - val_categorical_accuracy: 0.7500
#
# Epoch 00080: saving model to model_init_2019-06-2318_25_41.949303/model-00080-5.88401-0.97285-6.48621-0.75000.h5
# Epoch 81/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9335 - categorical_accuracy: 0.9600 - val_loss: 6.6183 - val_categorical_accuracy: 0.7600
#
# Epoch 00081: saving model to model_init_2019-06-2318_25_41.949303/model-00081-5.86929-0.97587-6.61827-0.76000.h5
# Epoch 82/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9625 - categorical_accuracy: 0.9575 - val_loss: 6.5156 - val_categorical_accuracy: 0.7700
#
# Epoch 00082: saving model to model_init_2019-06-2318_25_41.949303/model-00082-5.88624-0.97436-6.51562-0.77000.h5
# Epoch 83/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9645 - categorical_accuracy: 0.9500 - val_loss: 6.6591 - val_categorical_accuracy: 0.7400
#
# Epoch 00083: saving model to model_init_2019-06-2318_25_41.949303/model-00083-5.88533-0.96983-6.65905-0.74000.h5
# Epoch 84/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9552 - categorical_accuracy: 0.9525 - val_loss: 6.6401 - val_categorical_accuracy: 0.7500
#
# Epoch 00084: saving model to model_init_2019-06-2318_25_41.949303/model-00084-5.87822-0.97134-6.64015-0.75000.h5
# Epoch 85/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9874 - categorical_accuracy: 0.9450 - val_loss: 6.7352 - val_categorical_accuracy: 0.7300
#
# Epoch 00085: saving model to model_init_2019-06-2318_25_41.949303/model-00085-5.89655-0.96682-6.73518-0.73000.h5
# Epoch 86/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.8900 - categorical_accuracy: 0.9650 - val_loss: 6.5468 - val_categorical_accuracy: 0.7700
#
# Epoch 00086: saving model to model_init_2019-06-2318_25_41.949303/model-00086-5.83660-0.97888-6.54677-0.77000.h5
# Epoch 87/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9700 - categorical_accuracy: 0.9500 - val_loss: 6.4785 - val_categorical_accuracy: 0.8000
#
# Epoch 00087: saving model to model_init_2019-06-2318_25_41.949303/model-00087-5.88207-0.96983-6.47846-0.80000.h5
# Epoch 88/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9581 - categorical_accuracy: 0.9500 - val_loss: 6.5033 - val_categorical_accuracy: 0.7700
#
# Epoch 00088: saving model to model_init_2019-06-2318_25_41.949303/model-00088-5.87335-0.96983-6.50333-0.77000.h5
# Epoch 89/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9276 - categorical_accuracy: 0.9575 - val_loss: 6.5262 - val_categorical_accuracy: 0.8000
#
# Epoch 00089: saving model to model_init_2019-06-2318_25_41.949303/model-00089-5.85430-0.97436-6.52623-0.80000.h5
# Epoch 90/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9303 - categorical_accuracy: 0.9550 - val_loss: 6.5062 - val_categorical_accuracy: 0.7500
#
# Epoch 00090: saving model to model_init_2019-06-2318_25_41.949303/model-00090-5.85448-0.97285-6.50619-0.75000.h5
# Epoch 91/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9205 - categorical_accuracy: 0.9525 - val_loss: 6.4727 - val_categorical_accuracy: 0.7800
#
# Epoch 00091: saving model to model_init_2019-06-2318_25_41.949303/model-00091-5.84671-0.97134-6.47273-0.78000.h5
# Epoch 92/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9397 - categorical_accuracy: 0.9475 - val_loss: 6.4494 - val_categorical_accuracy: 0.7900
#
# Epoch 00092: saving model to model_init_2019-06-2318_25_41.949303/model-00092-5.85719-0.96833-6.44936-0.79000.h5
# Epoch 93/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9234 - categorical_accuracy: 0.9500 - val_loss: 6.4615 - val_categorical_accuracy: 0.7700
#
# Epoch 00093: saving model to model_init_2019-06-2318_25_41.949303/model-00093-5.84589-0.96983-6.46154-0.77000.h5
# Epoch 94/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.8901 - categorical_accuracy: 0.9600 - val_loss: 6.6159 - val_categorical_accuracy: 0.7200
#
# Epoch 00094: saving model to model_init_2019-06-2318_25_41.949303/model-00094-5.82478-0.97587-6.61588-0.72000.h5
# Epoch 95/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9477 - categorical_accuracy: 0.9500 - val_loss: 6.5322 - val_categorical_accuracy: 0.7700
#
# Epoch 00095: saving model to model_init_2019-06-2318_25_41.949303/model-00095-5.85837-0.96983-6.53218-0.77000.h5
# Epoch 96/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9199 - categorical_accuracy: 0.9525 - val_loss: 6.4562 - val_categorical_accuracy: 0.7800
#
# Epoch 00096: saving model to model_init_2019-06-2318_25_41.949303/model-00096-5.83875-0.97134-6.45616-0.78000.h5
# Epoch 97/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.8814 - categorical_accuracy: 0.9550 - val_loss: 6.6470 - val_categorical_accuracy: 0.7300
#
# Epoch 00097: saving model to model_init_2019-06-2318_25_41.949303/model-00097-5.81256-0.97285-6.64698-0.73000.h5
# Epoch 98/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9378 - categorical_accuracy: 0.9500 - val_loss: 6.5116 - val_categorical_accuracy: 0.7900
#
# Epoch 00098: saving model to model_init_2019-06-2318_25_41.949303/model-00098-5.84702-0.96983-6.51161-0.79000.h5
# Epoch 99/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.9136 - categorical_accuracy: 0.9475 - val_loss: 6.5445 - val_categorical_accuracy: 0.7700
#
# Epoch 00099: saving model to model_init_2019-06-2318_25_41.949303/model-00099-5.83041-0.96833-6.54452-0.77000.h5
# Epoch 100/100
# 17/17 [==============================] - 75s 4s/step - loss: 5.8648 - categorical_accuracy: 0.9600 - val_loss: 6.5520 - val_categorical_accuracy: 0.7500
#
# Epoch 00100: saving model to model_init_2019-06-2318_25_41.949303/model-00100-5.79901-0.97587-6.55195-0.75000.h5

# %% [markdown]
# ### The best accuracy values of the CNN-RNN model were received in Epoch# 100
# #### Training accuracy --> 0.97587
# #### Validation accuracy --> 0.7500

# %%
weights_path = './model-00100-5.79901-0.97587-6.55195-0.75000.h5'
gru_model.load_weights(weights_path)

# %%
print(gru_model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 10, 224, 224, 3)   0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 10, 512)           24636800
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 10, 512)           0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 64)                110784
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 24,747,909
# Trainable params: 16,136,197
# Non-trainable params: 8,611,712
# _________________________________________________________________
# None
